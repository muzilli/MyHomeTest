# %% [markdown]
# # Demo 3 - Convolutional Neural Networks usando Keras e Ckeras-introIFAR-10
#
# ### 1. Carregando a base CIFAR-10 (imagens rotuladas em macro categorias)
#
# *** Mais informações em https://www.cs.toronto.edu/~kriz/cifar.html ***

# %%
# %tensorflow_version 1.x
import tensorflow
import keras
from keras.datasets import cifar10

#carregando o dataset pré-embaralhado de treinamento bem como os dados de teste
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %% [markdown]
# ### 2. Visualizando as primeiras 24 imagens do dataset de treinamento

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Redimensionando as imagens e dividindo cada pixel em cada imagem por 255

# %%
# redimensionamento [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Dividindo o dataset em treinamento, teste e validação

# %%
from keras.utils import np_utils

# "one-hot encode" aplicado aos rótulos
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# divindo dataset de treinamento em treinamento, teste e validação
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# impressão da forma do conjunto de treino
print('x_train shape:', x_train.shape)

# impressão do número de imagens nos datasets de treinamento, teste e validação
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# ('x_train shape:', (45000, 32, 32, 3))
# (45000, 'train samples')
# (10000, 'test samples')
# (5000, 'validation samples')

# %% [markdown]
# ### 5. Definindo a arquitetura do modelo (IMPORTANTE!)
#
# * 3 camadas convolucionais de tamanho progressivamente crescente
# * Máximo de camadas de "pooling" (2x2) seguidas por tais 3 camadas convolucionais
# * Uma camada do tipo totalmente conectada de 100 neurônios
# * Últimas camadas do tipo totalmente conectadas de 10 saídas (10 classes de categoria de imagem)
# * "Dropout" de 0,2-0,3

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# tentem com outras funções de ativação (como visto em nossa Aula 3)
# mais informações em https://keras.io/activations/

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               204900
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 247,478
# Trainable params: 247,478
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compilando o modelo

# %%
# compilando o modelo escolhendo como se dará nossa perda, otimização e métricas (parâmetros do Keras)
# mais informações em https://keras.io/losses/
# mais informações em https://keras.io/optimizers/
# mais informações em https://keras.io/metrics/
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Treinando o modelo

# %%
from keras.callbacks import ModelCheckpoint   

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=64, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)

# tentem mudar o número de épocas de treinamento e verificar o comportamento de nosso algoritmo
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 61s - loss: 1.7243 - accuracy: 0.3738 - val_loss: 1.3836 - val_accuracy: 0.5066
#
# Epoch 00001: val_loss improved from inf to 1.38360, saving model to model.weights.best.hdf5
# Epoch 2/20
#  - 61s - loss: 1.3837 - accuracy: 0.5041 - val_loss: 1.3194 - val_accuracy: 0.5216
#
# Epoch 00002: val_loss improved from 1.38360 to 1.31938, saving model to model.weights.best.hdf5
# Epoch 3/20
#  - 60s - loss: 1.2440 - accuracy: 0.5584 - val_loss: 1.1373 - val_accuracy: 0.6018
#
# Epoch 00003: val_loss improved from 1.31938 to 1.13732, saving model to model.weights.best.hdf5
# Epoch 4/20
#  - 60s - loss: 1.1475 - accuracy: 0.5930 - val_loss: 1.2641 - val_accuracy: 0.5796
#
# Epoch 00004: val_loss did not improve from 1.13732
# Epoch 5/20
#  - 61s - loss: 1.0709 - accuracy: 0.6249 - val_loss: 1.1440 - val_accuracy: 0.6014
#
# Epoch 00005: val_loss did not improve from 1.13732
# Epoch 6/20
#  - 61s - loss: 1.0198 - accuracy: 0.6451 - val_loss: 1.0648 - val_accuracy: 0.6290
#
# Epoch 00006: val_loss improved from 1.13732 to 1.06477, saving model to model.weights.best.hdf5
# Epoch 7/20
#  - 61s - loss: 0.9738 - accuracy: 0.6620 - val_loss: 0.9355 - val_accuracy: 0.6782
#
# Epoch 00007: val_loss improved from 1.06477 to 0.93553, saving model to model.weights.best.hdf5
# Epoch 8/20
#  - 61s - loss: 0.9441 - accuracy: 0.6727 - val_loss: 0.9050 - val_accuracy: 0.6884
#
# Epoch 00008: val_loss improved from 0.93553 to 0.90503, saving model to model.weights.best.hdf5
# Epoch 9/20
#  - 61s - loss: 0.9134 - accuracy: 0.6849 - val_loss: 0.9474 - val_accuracy: 0.6948
#
# Epoch 00009: val_loss did not improve from 0.90503
# Epoch 10/20
#  - 61s - loss: 0.8938 - accuracy: 0.6924 - val_loss: 0.8968 - val_accuracy: 0.6936
#
# Epoch 00010: val_loss improved from 0.90503 to 0.89681, saving model to model.weights.best.hdf5
# Epoch 11/20
#  - 61s - loss: 0.8735 - accuracy: 0.7004 - val_loss: 0.8808 - val_accuracy: 0.7088
#
# Epoch 00011: val_loss improved from 0.89681 to 0.88082, saving model to model.weights.best.hdf5
# Epoch 12/20
#  - 61s - loss: 0.8678 - accuracy: 0.7038 - val_loss: 0.9140 - val_accuracy: 0.7114
#
# Epoch 00012: val_loss did not improve from 0.88082
# Epoch 13/20
#  - 61s - loss: 0.8524 - accuracy: 0.7114 - val_loss: 1.0090 - val_accuracy: 0.6860
#
# Epoch 00013: val_loss did not improve from 0.88082
# Epoch 14/20
#  - 61s - loss: 0.8439 - accuracy: 0.7166 - val_loss: 0.8751 - val_accuracy: 0.7082
#
# Epoch 00014: val_loss improved from 0.88082 to 0.87512, saving model to model.weights.best.hdf5
# Epoch 15/20
#  - 61s - loss: 0.8401 - accuracy: 0.7169 - val_loss: 0.9094 - val_accuracy: 0.7038
#
# Epoch 00015: val_loss did not improve from 0.87512
# Epoch 16/20
#  - 60s - loss: 0.8317 - accuracy: 0.7192 - val_loss: 1.0021 - val_accuracy: 0.7026
#
# Epoch 00016: val_loss did not improve from 0.87512
# Epoch 17/20
#  - 61s - loss: 0.8204 - accuracy: 0.7224 - val_loss: 1.0417 - val_accuracy: 0.6956
#
# Epoch 00017: val_loss did not improve from 0.87512
# Epoch 18/20
#  - 60s - loss: 0.8240 - accuracy: 0.7234 - val_loss: 0.9940 - val_accuracy: 0.6888
#
# Epoch 00018: val_loss did not improve from 0.87512
# Epoch 19/20
#  - 61s - loss: 0.8194 - accuracy: 0.7255 - val_loss: 0.8248 - val_accuracy: 0.7386
#
# Epoch 00019: val_loss improved from 0.87512 to 0.82480, saving model to model.weights.best.hdf5
# Epoch 20/20
#  - 61s - loss: 0.8161 - accuracy: 0.7269 - val_loss: 0.9788 - val_accuracy: 0.6960
#
# Epoch 00020: val_loss did not improve from 0.82480

# %% [markdown]
# ### 8. Carregando o modelo com a melhor precisão de validação

# %%
# carregando os pesos que geraram a melhor precisão de validação
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Cálculo da precisão de classificação no dataset de testes

# %%
# avaliar e imprimir a precisão do teste
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# ('\n', 'Test accuracy:', 0.7283999919891357)

# %% [markdown]
# ### 10. Visualizar algumas predições
#
# As visualizações podem nos dar algumas dicas sobre por que a rede classifica erroneamente alguns objetos.

# %%
# obtendo previsões no conjunto de testes
y_hat = model.predict(x_test)

# definindo rótulos de texto (rótulos disponíveis na fonte original: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot de amostra aleatória de imagens de teste, rótulos preditos e a "ground truth" advinda do dataset CIFAR-10
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
    # amostras corretamente classificadas em verde, incorretamente classificadas em vermelho
